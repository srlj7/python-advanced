# %%
# Cell 1: استيراد المكاتب
import pandas as pd

# Cell 2: إنشاء بيانات تجريبية (فوضوية قليلاً)
data = {
    'email': ['saif@gmail.com', 'ALI@hotmail.com', 'noor@yahoo.com', 'invalid_mail'],
    'score': [85, 90, 120, 88]  # لاحظ الرقم 120 (درجة غير منطقية)
}
df = pd.DataFrame(data)

# Cell 3: رؤية البيانات بعينك
print("البيانات الخام:")
display(df)  # في النوت بوك نستخدم display بدلاً من print للجمالية
